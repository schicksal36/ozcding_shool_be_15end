# %% [markdown]
# 1. **`employees 테이블을 생성해주세요`**
#     - `속성명 **id의** 자료형은 INT입니다. 추가로 자동으로 1씩 증가하도록 설정하고 기본키로 지정합니다.`
#     - `속성명 **name의** 자료형은 VARCHAR(100)입니다.`
#     - `속성명 **position의** 자료형은 VARCHAR(100)입니다.`
#     - `속성명 **salary의** 자료형은 DECIMAL(10, 2)입니다.`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **AUTO_INCREMENT 이부분이 오타나서 애러가 난것으로 추측 합니다;;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. **직원 데이터를 `employees`에 추가해주세요**
#     - 이름: 혜린, 직책: PM, 연봉: 90000
#     - 이름: 은우, 직책: Frontend, 연봉: 80000
#     - 이름: 가을, 직책: Backend, 연봉: 92000
#     - 이름: 지수, 직책: Frontend, 연봉: 7800
#     - 이름: 민혁, 직책: Frontend, 연봉: 96000
#     - 이름: 하온, 직책: Backend, 연봉: 130000
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# 에러난건 문자열에 ''안해서 애러난것으로 추측을 하였습니다.

# %% [markdown]
# 3. **모든 직원의 이름과 연봉 정보만을 조회하는 쿼리를 작성해주세요**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 에러는 테이블지정 안해서 났습니다.;;
#
# 아 문제를 잘못이해서 전체 테이블조회를 했네요;;
# 이름이랑 연봉정보만 했습니다;;;
#
# 첫번째꺼는  select name salary from employees 이거인데 name에 , 안찍어서 이렇게 된 것으로 추측합니다.

# %% [markdown]
# 4.Frontend 직책을 가진 직원 중에서 연봉이 90000 이하인 직원의 이름과 연봉을 조회하세요.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  * ERROR 1064 (42000): You have an error in your SQL syntax; check the manual - that corresponds to your MySQL server version for the right syntax to use near 'where position = 'Frontend' amd salary <= 90000' at line 1
#
#  검색사항에 테이블이름 지정안하고 오타때문에  생겼습니다;;;
# - select * from where position = Frontend amd salary <= 90000;
# 이구문을
# - select * from employees where position = 'Frontend' and salary <= 90000;
# 이구문으로 수정하였습니다.

# %% [markdown]
# 4.PM 직책을 가진 모든 직원의 연봉을 10% 인상한 후 그 결과를 확인하세요.(CEO 도.....ㅎㅎㅎ)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ERROR 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '='PM'' at line 1
#
# - 이 애러는 where='PM'이구문에서 position(칼럼,속성)지정 안해줘서 생겼습니다;;
#
# - UPDATE employees SET salary = salary +10% WHERE position='PM'
#
# - 원래는 위에 구문을 쓰려고 했는데 검색해보니 %는 문법오류라고 해서... 1.10으로 바꾸었습니다

# %% [markdown]
# 5.모든 Backend' 직책을 가진 직원의 연봉을 5% 인상하세요.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위에 꺼랑 똑같은거라서요;;;

# %% [markdown]
# 6.민혁 사원의 데이터를 삭제하세요.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 마지막 모든 직원을 position 별로 그룹화하여 각 직책의 평균 연봉을 계산하세요.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  왜 애러 났는지 감을 못잡았습니다 ;;;

# %% [markdown]
# 7.employees 테이블을 삭제&백업하세요.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 일단 source 명령어로 백업을 먼저했습니다.
# - source이방식은 sql내부에서 작동하는방식인데 알아보니 기존파일을 덮어 씨우는  방식이더라구요.
#
# - 오류난 이유는 알고보니 기존파일이 없어서 오류가 난것으로 추측합니다.
#
# - 다른 백업방식은 mysqldump -u root -p mydb > 파일명.sql 이고 복구는 mysqldump -u root -p mydb > 파일명.sql입니다.
